# %% [markdown]
# pillow中最重要的是lmage类，读取和处理图像都要通过这个类来完成

# %%
from PIL import Image

# %%
image1 = Image.open('C:/Users/a/Desktop/image.jpg')
image1.format,image1.size,image1.mode
('JPEG', (500, 750), 'RGB')
image1.show()
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x210 at 0x29A6D4F7860>

# %% [markdown]
# 剪裁图像

# %%
image2 = Image.open('C:/Users/a/Desktop/images.jpg')
rect = 80,20,310,360
image2.crop(rect).show()
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x29A6D5AC9E8>

# %% [markdown]
# 生成缩略图

# %%
size = 128,128
image2.thumbnail(size)
image2.show()
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x85 at 0x21F4A881B38>

# %% [markdown]
# 缩放和黏贴图像

# %%
guido_head = image2.crop(rect)
width, height = guido_head.size
image1.paste(guido_head.resize((int(width / 1.5), int(height / 1.5))), (172, 40))
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x210 at 0x21F4A881D30>

# %% [markdown]
# 旋转和翻转

# %%
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x210 at 0x21F4A881D30>

# %%
image1.rotate(180).show()

# %%
image1.transpose(Image.FLIP_LEFT_RIGHT).show()

# %% [markdown]
# 操作像素

# %%
image2.size
# Out:
# (275, 183)

# %%
image2 = Image.open('C:/Users/a/Desktop/images.jpg')
for x in range(80,275):
    for y in range(20,183):
        image2.putpixel((x,y),(128,128,128))
image2.show()

# %% [markdown]
# 滤镜效果

# %%
from PIL import Image,ImageFilter

# %%
image = Image.open('C:/Users/a/Desktop/images.jpg')

# %%
image.filter(ImageFilter.CONTOUR).show()

# %% [markdown]
# 处理Excel电子表格

# %% [markdown]
# python的openpyxl模块让我们可以在python程序中读取和修改Excel电子表格

# %% [markdown]
# 处理word文档

# %% [markdown]
# 利用python-docx模块，Pytho 可以创建和修改Word文档，当然这里的Word文档不仅仅是指通过微软的Office软件创建的扩展名为docx的文档，LibreOffice Writer和OpenOffice Writer都是免费的字处理软件。

# %% [markdown]
# 处理PDF文档

# %% [markdown]
# PDF是Portable Document Format的缩写，使用.pdf作为文件扩展名。接下来我们就研究一下如何通过Python实现从PDF读取文本内容和从已有的文档生成新的PDF文件。
